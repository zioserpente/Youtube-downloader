# %%
import yt_dlp

def scarica_video(url, path_destinazione=r"C:\Users\moone\Downloads"):
    try:
       
        ydl_opts = {
            'outtmpl': f'{path_destinazione}/%(title)s.%(ext)s',
            'writethumbnail': True,     
            'postprocessors': [
                {  
                    'key': 'EmbedThumbnail',
                },
                {  
                    'key': 'FFmpegMetadata',
                }
            ],
        }
        with yt_dlp.YoutubeDL(ydl_opts) as ydl:
            
            info_dict = ydl.extract_info(url, download=False)
            video_title = info_dict.get('title', 'Video senza titolo')
            formats = info_dict.get('formats', [])
            #print(formats)



            filtered_formats = [fmt for fmt in formats if fmt.get('acodec') != 'none' and (fmt['ext'] == 'm4a' or fmt['ext'] == 'mp4')]
            

           
            print(f"Formati disponibili per il video '{video_title}':")
            for fmt in filtered_formats:
                print(f"ID: {fmt['format_id']}, Estensione: {fmt['ext']}, Risoluzione: {fmt.get('resolution', 'n/a')}, Note: {fmt.get('format_note', '')}")
            
          
            format_id = input("Inserisci l'ID del formato che desideri scaricare: ")

            
            ydl_opts['format'] = format_id

            print(f"Download iniziato: {video_title}")
            ydl = yt_dlp.YoutubeDL(ydl_opts)
            ydl.download([url])  
            print(f"Download completato: {video_title}")
    except Exception as e:
        print(f"Si è verificato un errore: {e}")

if __name__ == "__main__":
    url_video = input("Inserisci l'URL del video di YouTube: ")
    percorso_destinazione = input("Inserisci il percorso di destinazione (premi invio per default: Downloads): ") or r"C:\Users\moone\Downloads"

    scarica_video(url_video, percorso_destinazione)
# Out:
# [youtube] Extracting URL: https://m.youtube.com/watch?v=ifcpuP_NVWM&pp=2AEAkAIB
# [youtube] ifcpuP_NVWM: Downloading webpage
# [youtube] ifcpuP_NVWM: Downloading ios player API JSON
# [youtube] ifcpuP_NVWM: Downloading mweb player API JSON
# [youtube] ifcpuP_NVWM: Downloading player 9fe2e06e
# WARNING: [youtube] Falling back to generic n function search
#          player = https://www.youtube.com/s/player/9fe2e06e/player_ias.vflset/en_US/base.js
# WARNING: [youtube] ifcpuP_NVWM: nsig extraction failed: Some formats may be missing
#          n = BIs8S7E48mRwazia0 ; player = https://www.youtube.com/s/player/9fe2e06e/player_ias.vflset/en_US/base.js
# WARNING: [youtube] Falling back to generic n function search
#          player = https://www.youtube.com/s/player/9fe2e06e/player_ias.vflset/en_US/base.js
# WARNING: [youtube] ifcpuP_NVWM: nsig extraction failed: Some formats may be missing
#          n = YqfMRRXIY6A3NQ0mA ; player = https://www.youtube.com/s/player/9fe2e06e/player_ias.vflset/en_US/base.js
# [youtube] ifcpuP_NVWM: Downloading m3u8 information
# Formati disponibili per il video '✅RIPASSO riassunto TUTTA LA STORIA D'ITALIA dal 1861-2021. Programma storia 5°/ esame maturità part2':
# ID: 233, Estensione: mp4, Risoluzione: audio only, Note: Default
# ID: 234, Estensione: mp4, Risoluzione: audio only, Note: Default
# ID: 139-drc, Estensione: m4a, Risoluzione: audio only, Note: low, DRC
# ID: 139, Estensione: m4a, Risoluzione: audio only, Note: low
# ID: 140-drc, Estensione: m4a, Risoluzione: audio only, Note: medium, DRC
# ID: 140, Estensione: m4a, Risoluzione: audio only, Note: medium
# Download iniziato: ✅RIPASSO riassunto TUTTA LA STORIA D'ITALIA dal 1861-2021. Programma storia 5°/ esame maturità part2
# [youtube] Extracting URL: https://m.youtube.com/watch?v=ifcpuP_NVWM&pp=2AEAkAIB
# [youtube] ifcpuP_NVWM: Downloading webpage
# [youtube] ifcpuP_NVWM: Downloading ios player API JSON
# [youtube] ifcpuP_NVWM: Downloading mweb player API JSON
# [youtube] ifcpuP_NVWM: Downloading player 9fe2e06e
# WARNING: [youtube] Falling back to generic n function search
#          player = https://www.youtube.com/s/player/9fe2e06e/player_ias.vflset/en_US/base.js
# WARNING: [youtube] ifcpuP_NVWM: nsig extraction failed: Some formats may be missing
#          n = Q0RMWR8p6yiC6QBgW ; player = https://www.youtube.com/s/player/9fe2e06e/player_ias.vflset/en_US/base.js
# WARNING: [youtube] Falling back to generic n function search
#          player = https://www.youtube.com/s/player/9fe2e06e/player_ias.vflset/en_US/base.js
# WARNING: [youtube] ifcpuP_NVWM: nsig extraction failed: Some formats may be missing
#          n = -6E8QRp-NDU23Q_sj ; player = https://www.youtube.com/s/player/9fe2e06e/player_ias.vflset/en_US/base.js
# [youtube] ifcpuP_NVWM: Downloading m3u8 information
# [info] ifcpuP_NVWM: Downloading 1 format(s): 139
# [download] Destination: Shit scaricata\✅RIPASSO riassunto TUTTA LA STORIA D'ITALIA dal 1861-2021. Programma storia 5°⧸ esame maturità part2.m4a
# [download] 100% of   10.80MiB in 00:00:03 at 3.24MiB/s
# WARNING: ifcpuP_NVWM: writing DASH m4a. Only some players support this container. Install ffmpeg to fix this automatically
# Download completato: ✅RIPASSO riassunto TUTTA LA STORIA D'ITALIA dal 1861-2021. Programma storia 5°/ esame maturità part2

# %%
#versione vecchia non funzionante con pytube


from pytube import YouTube

def scarica_video(url, path_destinazione="Shit scaricata"):
    try:
        
        yt = YouTube(url)

       
        stream = yt.streams.get_highest_resolution()

        
        print(f"download iniziato: {yt.title}")
        stream.download(output_path=path_destinazione)
        print(f"Download completato: {yt.title}")
    except Exception as e:
        print(f"Si è verificato un errore buffo buffo: {e}")

if __name__ == "__main__":
    
    url_video = input("Inserisci l'URL del video di YouTube: ")
    
    percorso_destinazione = input("Inserisci il percorso di destinazione (premi invio per default): ") or "Shit scaricata"

    scarica_video(url_video, percorso_destinazione)
# Out:
# Si è verificato un errore buffo buffo: HTTP Error 400: Bad Request
